# %% [markdown]
# # LLaMA 3.1
#
# This notebook use LLaMA 3.1 for infering if texts are written by LLM. There is no finetuning performed. The model will be tested in 0-shot and 5-shot prompting.

# %% [markdown]
# # Load model

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch
from transformers import logging
logging.set_verbosity_warning()
logging.set_verbosity_error()

import pandas as pd
import numpy as np
from sklearn.metrics import f1_score
import tqdm

device = "cuda" # the device to load the model onto

token = ''
model_id = "meta-llama/Meta-Llama-3-8B-Instruct"

tokenizer = AutoTokenizer.from_pretrained(model_id, token=token, torch_dtype=torch.float16)
model = AutoModelForCausalLM.from_pretrained(model_id, token=token, torch_dtype=torch.float16)
model.to(device)

# %% [markdown]
# # Load data

# %%
dataset = 'SQUAD_GPT4'

import pandas as pd
import numpy as np

data = pd.read_csv(f'Data/{dataset}.csv', encoding = "ISO-8859-1")
data.head()

# %% [markdown]
# # Zero-shot Prompting

# %%
f1s = []

for seed in [1111, 2222,3333,4444,5555,6666,7777,8888,9999,1010]:
    np.random.seed(seed)
    print(seed)
    sampling_indices = np.random.uniform(0,1,data.shape[0])
    train_data = data.loc[sampling_indices < 0.9]
    test_data = data.loc[sampling_indices >= 0.9]
    train_data = pd.DataFrame({'text':pd.concat([train_data['answer'], train_data['gpt1'], train_data['gpt2']]),
                               'label':[0]*train_data.shape[0] + [1]*train_data.shape[0]*2})
    test_data = pd.DataFrame({'text':pd.concat([test_data['answer'], test_data['gpt2']]),
                               'label':[0]*test_data.shape[0]+[1]*test_data.shape[0]})

    outs = []
    for text in tqdm.tqdm(test_data['text']):
        messages = [
            {'role': 'system', 'content': f'act as an AI content detector, determine the text wrapped in triple quotes """<text>""" was written by human or not. answer "yes" or "no" only'},
            {'role': 'user', 'content': f'"""{text}"""'}
        ]

        encodeds = tokenizer.apply_chat_template(messages, add_generation_prompt=True, return_tensors="pt")

        terminators = [
            tokenizer.eos_token_id,
            tokenizer.convert_tokens_to_ids("<|eot_id|>")
        ]

        model_inputs = encodeds.to(device)

        generated_ids = model.generate(model_inputs, max_new_tokens=2, eos_token_id=terminators, do_sample=True)
        response = generated_ids[0][model_inputs.shape[-1]:]
        decoded = tokenizer.decode(response)
        outs.append(decoded)

    outs_bin = [0 if 'yes' in s.lower() else 1 for s in outs]
    f1s.append(f1_score(test_data['label'], outs_bin))
    
np.mean(f1s)

# %% [markdown]
# # Five-shot Prompting

# %%
f1s = []

for seed in [1111, 2222,3333,4444,5555,6666,7777,8888,9999,1010]:
    np.random.seed(seed)
    print(seed)
    #split
    sampling_indices = np.random.uniform(0,1,data.shape[0])
    train_data = data.loc[sampling_indices < 0.9]
    test_data = data.loc[sampling_indices >= 0.9]
    train_data = pd.DataFrame({'text':pd.concat([train_data['answer'], train_data['gpt1'], train_data['gpt2']]),
                               'label':[0]*train_data.shape[0] + [1]*train_data.shape[0]*2})
    test_data = pd.DataFrame({'text':pd.concat([test_data['answer'], test_data['gpt2']]),
                               'label':[0]*test_data.shape[0]+[1]*test_data.shape[0]})
    
    #run model
    outs = []
    for text in tqdm.tqdm(test_data['text']):
        #get examples
        messages = [
            {'role': 'system', 'content': f'act as an AI content detector, determine the text wrapped in triple quotes """<text>""" was written by human or not. answer "yes" or "no" only'},
        ]
        for r in train_data.sample(5).iterrows():
            messages.append({'role': 'user', 'content': f'"""{r[1]["text"]}"""'})
            messages.append({'role': 'assistant', 'content' : f'{"yes" if r[1]["label"]==0 else "no"}'})
        #add input text
        messages.append({'role': 'user', 'content': f'"""{text}"""'})

        encodeds = tokenizer.apply_chat_template(messages, add_generation_prompt=True, return_tensors="pt")

        terminators = [
            tokenizer.eos_token_id,
            tokenizer.convert_tokens_to_ids("<|eot_id|>")
        ]

        model_inputs = encodeds.to(device)

        generated_ids = model.generate(model_inputs, max_new_tokens=2, eos_token_id=terminators, do_sample=True)
        response = generated_ids[0][model_inputs.shape[-1]:]
        decoded = tokenizer.decode(response)
        outs.append(decoded)

    outs_bin = [0 if 'yes' in s.lower() else 1 for s in outs]
    f1s.append(f1_score(test_data['label'], outs_bin))
    
np.mean(f1s)
